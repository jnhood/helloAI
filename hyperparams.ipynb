# %% [markdown]
# <a href="https://colab.research.google.com/github/jnhood/helloAI/blob/main/hyperparams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://blog.infuseai.io/run-a-full-tty-terminal-in-google-colab-without-colab-pro-2759b9f8a74a
# xterm may be helpful for speeding up some of the parts of this assignment ... see in class instruction on usage
#!pip install colab-xterm
#%load_ext colabxterm
# !git clone "https://github.com/kartoone/nn3"
# !git pull
# Out:
# Cloning into 'nn3'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 145 (delta 19), reused 17 (delta 8), pack-reused 109
# Receiving objects: 100% (145/145), 94.35 MiB | 28.65 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# fatal: not a git repository (or any of the parent directories): .git

# %%
# %cd nn3/src
# Out:
# /content/nn3/src

# %%
from network import Network
import mnist_loader
import numpy as np
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = Network([784, 30, 10])
print(np.shape(net.biases))
print(net.biases)
# Out:
# (2,)
# [array([[ 0.3890983 ],
#        [-1.4696847 ],
#        [-1.05995763],
#        [ 0.53326891],
#        [-0.18046243],
#        [-1.35151824],
#        [ 0.12037031],
#        [-1.4208598 ],
#        [ 0.26093653],
#        [ 1.00190776],
#        [-1.08798114],
#        [-0.22462975],
#        [ 0.57862435],
#        [ 0.88537975],
#        [ 0.64023665],
#        [-3.54986475],
#        [-0.65000512],
#        [-1.48885244],
#        [-1.77266106],
#        [-0.27729905],
#        [-0.98275275],
#        [-1.62328244],
#        [ 0.41335562],
#        [-0.88494382],
#        [ 0.18081633],
#        [ 1.06606388],
#        [-0.62244406],
#        [-0.28893472],
#        [-1.48971008],
#        [-0.89162489]]), array([[ 0.69083998],
#        [ 0.11737126],
#        [ 0.53098267],
#        [ 0.87443507],
#        [ 0.66101932],
#        [ 1.63187109],
#        [ 0.62850321],
#        [ 1.75979223],
#        [-0.71728245],
#        [-0.73172399]])]
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:1970: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = asarray(a).shape

# %%
from network import Network
import mnist_loader
import time
import numpy as np

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
net = Network([784, 30, 10])
print(np.shape(net.biases))
print(net.biases)
# Out:
# (2,)
# [array([[-0.79896458],
#        [ 0.06236317],
#        [ 0.10693104],
#        [-0.41510227],
#        [ 0.07943556],
#        [-0.56173645],
#        [ 1.83252744],
#        [-1.83063943],
#        [ 0.69072484],
#        [-0.48994285],
#        [ 0.06794793],
#        [ 0.43785843],
#        [-0.27840638],
#        [ 0.51605631],
#        [-0.13809977],
#        [ 1.30475104],
#        [ 0.16334534],
#        [ 0.32616459],
#        [ 0.27698536],
#        [-2.38352436],
#        [ 1.31491061],
#        [-0.54176846],
#        [-0.49028981],
#        [ 0.23395368],
#        [-0.66561545],
#        [ 0.18229549],
#        [-0.69573533],
#        [ 1.9492136 ],
#        [-1.46649806],
#        [-1.45455793]]), array([[-0.15107815],
#        [ 0.67797498],
#        [ 1.23076366],
#        [ 1.55468854],
#        [ 0.20897157],
#        [-0.03073474],
#        [-2.73711821],
#        [ 0.15838291],
#        [-0.06828827],
#        [-0.88845139]])]

# %%
import numpy as np

# finds the image that the network has the hardest time classifying
def findTroublesomeImage(test_data, net):
  worsti = -1
  worsta = 1.0
  for i,(x,y) in enumerate(test_data):
    a = net.feedforward(x)
    if np.max(a)<worsta:
      worsta = np.max(a)
      worsti = i
  print(worsta)
  print(worsti)
  return worsti
# np.set_printoptions(linewidth=np.inf)
#ii = findTroublesomeImage(test_data)

#import matplotlib.pyplot as plt
#plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
#print(net.feedforward(test_data[ii][0]))
#print(test_data[ii][1])
# did the image get classified correctly? the above code should help!

# %%
from network import Network
import mnist_loader
import time

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
configs = [[784,15,10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10], ] # ADD THE REMAINING CONFIGS HERE!!!!training_times = []
training_times = []
accuracies = []
for config in configs:
    print(config)
    start = time.time()
    net = Network(config)
    accuracies.append(net.SGD(training_data[0:100], 30, 10, 3.0, test_data=test_data[0:100]))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net)
    import matplotlib.pyplot as plt
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# repeat the above IN DIFFERENT CELLS (don't do it all in one cell, you will thank me later) for all the structural configurations
# Out:
# [784, 15, 10]
# Epoch 0: starting...training completed in 0.02s...measuring accuracy...19 / 100 in 0.0s
# Epoch 1: starting...training completed in 0.01s...measuring accuracy...21 / 100 in 0.0s
# Epoch 2: starting...training completed in 0.01s...measuring accuracy...28 / 100 in 0.0s
# Epoch 3: starting...training completed in 0.01s...measuring accuracy...30 / 100 in 0.0s
# Epoch 4: starting...training completed in 0.01s...measuring accuracy...32 / 100 in 0.0s
# Epoch 5: starting...training completed in 0.01s...measuring accuracy...32 / 100 in 0.02s
# Epoch 6: starting...training completed in 0.01s...measuring accuracy...33 / 100 in 0.0s
# Epoch 7: starting...training completed in 0.01s...measuring accuracy...36 / 100 in 0.03s
# Epoch 8: starting...training completed in 0.01s...measuring accuracy...36 / 100 in 0.0s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.0s
# Epoch 10: starting...training completed in 0.01s...measuring accuracy...39 / 100 in 0.0s
# Epoch 11: starting...training completed in 0.01s...measuring accuracy...46 / 100 in 0.0s
# Epoch 12: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.0s
# Epoch 13: starting...training completed in 0.01s...measuring accuracy...46 / 100 in 0.0s
# Epoch 14: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.0s
# Epoch 15: starting...training completed in 0.01s...measuring accuracy...46 / 100 in 0.0s
# Epoch 16: starting...training completed in 0.01s...measuring accuracy...47 / 100 in 0.02s
# Epoch 17: starting...training completed in 0.01s...measuring accuracy...46 / 100 in 0.0s
# Epoch 18: starting...training completed in 0.01s...measuring accuracy...48 / 100 in 0.0s
# Epoch 19: starting...training completed in 0.01s...measuring accuracy...45 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.0s
# Epoch 21: starting...training completed in 0.01s...measuring accuracy...46 / 100 in 0.0s
# Epoch 22: starting...training completed in 0.01s...measuring accuracy...48 / 100 in 0.0s
# Epoch 23: starting...training completed in 0.01s...measuring accuracy...51 / 100 in 0.0s
# Epoch 24: starting...training completed in 0.01s...measuring accuracy...48 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.01s...measuring accuracy...51 / 100 in 0.0s
# Epoch 26: starting...training completed in 0.01s...measuring accuracy...50 / 100 in 0.0s
# Epoch 27: starting...training completed in 0.01s...measuring accuracy...50 / 100 in 0.0s
# Epoch 28: starting...training completed in 0.01s...measuring accuracy...50 / 100 in 0.0s
# Epoch 29: starting...training completed in 0.01s...measuring accuracy...53 / 100 in 0.0s
# 0.6083672046661377
# 0.052878271301278215
# 35
# [784, 30, 10]
# Epoch 0: starting...training completed in 0.03s...measuring accuracy...21 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.02s...measuring accuracy...25 / 100 in 0.0s
# Epoch 2: starting...training completed in 0.02s...measuring accuracy...30 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.02s...measuring accuracy...31 / 100 in 0.0s
# Epoch 4: starting...training completed in 0.02s...measuring accuracy...32 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.03s...measuring accuracy...35 / 100 in 0.0s
# Epoch 6: starting...training completed in 0.02s...measuring accuracy...36 / 100 in 0.0s
# Epoch 7: starting...training completed in 0.02s...measuring accuracy...37 / 100 in 0.0s
# Epoch 8: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.0s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.0s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.0s
# Epoch 11: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.0s
# Epoch 12: starting...training completed in 0.03s...measuring accuracy...41 / 100 in 0.0s
# Epoch 13: starting...training completed in 0.02s...measuring accuracy...44 / 100 in 0.0s
# Epoch 14: starting...training completed in 0.03s...measuring accuracy...46 / 100 in 0.0s
# Epoch 15: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.02s...measuring accuracy...47 / 100 in 0.0s
# Epoch 17: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.0s
# Epoch 18: starting...training completed in 0.03s...measuring accuracy...47 / 100 in 0.0s
# Epoch 19: starting...training completed in 0.02s...measuring accuracy...47 / 100 in 0.0s
# Epoch 20: starting...training completed in 0.02s...measuring accuracy...47 / 100 in 0.0s
# Epoch 21: starting...training completed in 0.02s...measuring accuracy...48 / 100 in 0.0s
# Epoch 22: starting...training completed in 0.02s...measuring accuracy...47 / 100 in 0.0s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...49 / 100 in 0.0s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...49 / 100 in 0.0s
# Epoch 25: starting...training completed in 0.02s...measuring accuracy...49 / 100 in 0.0s
# Epoch 26: starting...training completed in 0.02s...measuring accuracy...49 / 100 in 0.0s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...49 / 100 in 0.0s
# Epoch 28: starting...training completed in 0.02s...measuring accuracy...48 / 100 in 0.0s
# Epoch 29: starting...training completed in 0.03s...measuring accuracy...49 / 100 in 0.0s
# 0.773554801940918
# 0.039207355885613436
# 81
# [784, 100, 10]
# Epoch 0: starting...training completed in 0.04s...measuring accuracy...13 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.06s...measuring accuracy...18 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.04s...measuring accuracy...21 / 100 in 0.01s
# Epoch 3: starting...training completed in 0.05s...measuring accuracy...27 / 100 in 0.01s
# Epoch 4: starting...training completed in 0.04s...measuring accuracy...28 / 100 in 0.0s
# Epoch 5: starting...training completed in 0.04s...measuring accuracy...28 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.04s...measuring accuracy...28 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.05s...measuring accuracy...27 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.05s...measuring accuracy...28 / 100 in 0.0s
# Epoch 9: starting...training completed in 0.04s...measuring accuracy...29 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.05s...measuring accuracy...33 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.05s...measuring accuracy...33 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.05s...measuring accuracy...31 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.04s...measuring accuracy...32 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.04s...measuring accuracy...34 / 100 in 0.01s
# Epoch 15: starting...training completed in 0.06s...measuring accuracy...34 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.04s...measuring accuracy...36 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.04s...measuring accuracy...38 / 100 in 0.0s
# Epoch 18: starting...training completed in 0.05s...measuring accuracy...37 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.09s...measuring accuracy...42 / 100 in 0.02s
# Epoch 20: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.0s
# Epoch 23: starting...training completed in 0.05s...measuring accuracy...41 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.01s
# Epoch 25: starting...training completed in 0.05s...measuring accuracy...41 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.05s...measuring accuracy...41 / 100 in 0.01s
# Epoch 27: starting...training completed in 0.05s...measuring accuracy...41 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.04s...measuring accuracy...41 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.05s...measuring accuracy...42 / 100 in 0.01s
# 1.649097204208374
# 0.0014960457323253808
# 96
# [784, 15, 15, 10]
# Epoch 0: starting...training completed in 0.02s...measuring accuracy...20 / 100 in 0.01s
# Epoch 1: starting...training completed in 0.02s...measuring accuracy...22 / 100 in 0.01s
# Epoch 2: starting...training completed in 0.02s...measuring accuracy...25 / 100 in 0.0s
# Epoch 3: starting...training completed in 0.02s...measuring accuracy...25 / 100 in 0.01s
# Epoch 4: starting...training completed in 0.02s...measuring accuracy...31 / 100 in 0.01s
# Epoch 5: starting...training completed in 0.02s...measuring accuracy...27 / 100 in 0.01s
# Epoch 6: starting...training completed in 0.02s...measuring accuracy...33 / 100 in 0.01s
# Epoch 7: starting...training completed in 0.02s...measuring accuracy...33 / 100 in 0.01s
# Epoch 8: starting...training completed in 0.02s...measuring accuracy...34 / 100 in 0.01s
# Epoch 9: starting...training completed in 0.02s...measuring accuracy...35 / 100 in 0.01s
# Epoch 10: starting...training completed in 0.02s...measuring accuracy...38 / 100 in 0.01s
# Epoch 11: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.01s
# Epoch 12: starting...training completed in 0.04s...measuring accuracy...39 / 100 in 0.01s
# Epoch 13: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.01s
# Epoch 14: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.01s
# Epoch 15: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.01s
# Epoch 16: starting...training completed in 0.02s...measuring accuracy...40 / 100 in 0.01s
# Epoch 17: starting...training completed in 0.02s...measuring accuracy...39 / 100 in 0.01s
# Epoch 18: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.01s
# Epoch 19: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.01s
# Epoch 20: starting...training completed in 0.02s...measuring accuracy...43 / 100 in 0.01s
# Epoch 21: starting...training completed in 0.02s...measuring accuracy...42 / 100 in 0.01s
# Epoch 22: starting...training completed in 0.02s...measuring accuracy...41 / 100 in 0.01s
# Epoch 23: starting...training completed in 0.02s...measuring accuracy...47 / 100 in 0.01s
# Epoch 24: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.0s
# Epoch 25: starting...training completed in 0.05s...measuring accuracy...47 / 100 in 0.01s
# Epoch 26: starting...training completed in 0.02s...measuring accuracy...45 / 100 in 0.01s
# Epoch 27: starting...training completed in 0.02s...measuring accuracy...47 / 100 in 0.01s
# Epoch 28: starting...training completed in 0.02s...measuring accuracy...50 / 100 in 0.01s
# Epoch 29: starting...training completed in 0.02s...measuring accuracy...46 / 100 in 0.01s
# 0.761821985244751
# 0.10505311232207055
# 87

# %%
print(configs)
print(training_times)
print(accuracies)
# Out:
# [[784, 15, 10], [784, 30, 10], [784, 100, 10], [784, 15, 15, 10]]
# [0.6083672046661377, 0.773554801940918, 1.649097204208374, 0.761821985244751]
# [53, 49, 42, 46]

# %%
from network2 import Network
from network2 import QuadraticCost
import mnist_loader
import time
import matplotlib.pyplot as plt

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
configs = []
for epochs in [15, 30, 45, 100]:
    for batchsize in [5, 10, 20, 100]:
      for learningrate in [0.1, 0.5, 1.0, 3.0, 5.0]:
        configs.append([epochs, batchsize, learningrate])

  # only train on small slice (start with 100 ... but then once you have your graphs working ... bump it up to 1000 and re-run)
training_data = training_data[0:100]
test_data = test_data[0:100]

training_times = []
accuracies = []  
  # note that this will be a GIANT list of training times for each config plus the two cost functions. [time1, time2, time3, time4] ... 
  #  time1 and time2 are both associated with the single hidden layer network and differ in the cost function (time1 - crossentropy, time2-quadratic)
  #  time3 and time4 are both associated with the dual hidden layer network and differ in the cost function (time3 - crossentropy, time4-quadratic)
  # NOTE: once you are happy with the results ... remove the 0:1000 and use the complete training data
for config in configs:
    print(config, "single hidden layer plus cross-entropy")
    start = time.time()
    net1 = Network([784,15,10]) # cross-entropy cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "single hidden layer plus quadratic")
    start = time.time()
    net1 = Network([784, 15, 10],cost=QuadraticCost) # quadratic cost
    accuracies.append(net1.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net1)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    # repeat for the two layer network
    print(config, "dual hidden layers plus cross-entropy")
    start = time.time()
    net2 = Network([784,30,15,10])
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()

    print(config, "dual hidden layers plus quadratic")
    start = time.time()
    net2 = Network([784,30,15, 10],cost=QuadraticCost)
    accuracies.append(net2.SGD(training_data[0:100], config[0], config[1], config[2], evaluation_data=test_data[0:100], monitor_evaluation_accuracy=True))
    finish = time.time()
    elapsed = finish - start
    print(elapsed)
    training_times.append(elapsed)
    ii = findTroublesomeImage(test_data[0:100], net2)
    plt.imshow(255*np.reshape(test_data[ii][0],(28,28)),cmap="gray_r")
    plt.show()
# Out:
# [15, 5, 0.1] single hidden layer plus cross-entropy
# 0.2559034824371338
# 0.09780853102028819
# 35
# [15, 5, 0.1] single hidden layer plus quadratic
# 0.2745802402496338
# 0.12583952769829643
# 48
# [15, 5, 0.1] dual hidden layers plus cross-entropy
# 0.4158470630645752
# 0.14484515633738865
# 47
# [15, 5, 0.1] dual hidden layers plus quadratic
# 0.44579410552978516
# 0.1369014893384259
# 21
# [15, 5, 0.5] single hidden layer plus cross-entropy
# 0.24030280113220215
# 0.0841236716334278
# 59
# [15, 5, 0.5] single hidden layer plus quadratic
# 0.25539731979370117
# 0.13291354490903307
# 63
# [15, 5, 0.5] dual hidden layers plus cross-entropy
# 0.4380178451538086
# 0.0792800777142455
# 87
# [15, 5, 0.5] dual hidden layers plus quadratic
# 0.44249749183654785
# 0.13676982067457494
# 51
# [15, 5, 1.0] single hidden layer plus cross-entropy
# 0.22274112701416016
# 0.04297430066578038
# 11
# [15, 5, 1.0] single hidden layer plus quadratic
# 0.24840474128723145
# 0.16368635099427775
# 11
# [15, 5, 1.0] dual hidden layers plus cross-entropy
# 0.4016251564025879
# 0.027423306752153195
# 23
# [15, 5, 1.0] dual hidden layers plus quadratic
# 0.44008755683898926
# 0.14304870627569422
# 87
# [15, 5, 3.0] single hidden layer plus cross-entropy
# 0.2395029067993164
# 0.3515764372120708
# 77
# [15, 5, 3.0] single hidden layer plus quadratic
# 0.2652106285095215
# 0.130082764700638
# 66
# [15, 5, 3.0] dual hidden layers plus cross-entropy
# 0.40725111961364746
# 0.10438749584599595
# 8
# [15, 5, 3.0] dual hidden layers plus quadratic
# 0.43732786178588867
# 0.07489207800803867
# 43
# [15, 5, 5.0] single hidden layer plus cross-entropy
# 0.23920011520385742
# 0.18379749844292517
# 65
# [15, 5, 5.0] single hidden layer plus quadratic
# 0.24375605583190918
# 0.09102160340930603
# 8
# [15, 5, 5.0] dual hidden layers plus cross-entropy
# 0.40648794174194336
# 0.1888803928931474
# 75
# [15, 5, 5.0] dual hidden layers plus quadratic
# 0.4763796329498291
# 0.1540636295775302
# 66
# [15, 10, 0.1] single hidden layer plus cross-entropy
# 0.2306675910949707
# 0.1306113182845359
# 95
# [15, 10, 0.1] single hidden layer plus quadratic
# 0.2527191638946533
# 0.13340280077054303
# 95
# [15, 10, 0.1] dual hidden layers plus cross-entropy
# 0.3882737159729004
# 0.13598929699501344
# 68
# [15, 10, 0.1] dual hidden layers plus quadratic
# 0.4128129482269287
# 0.14506856217044725
# 51
# [15, 10, 0.5] single hidden layer plus cross-entropy
# 0.2278146743774414
# 0.09803408250909294
# 34
# [15, 10, 0.5] single hidden layer plus quadratic
# 0.2484452724456787
# 0.13870703112049826
# 95
# [15, 10, 0.5] dual hidden layers plus cross-entropy
# 0.4027082920074463
# 0.1170381738543421
# 52
# [15, 10, 0.5] dual hidden layers plus quadratic
# 0.4013023376464844
# 0.13128196229178196
# 48
# [15, 10, 1.0] single hidden layer plus cross-entropy
# 0.2268986701965332
# 0.06877711421769919
# 59
# [15, 10, 1.0] single hidden layer plus quadratic
# 0.2532339096069336
# 0.15903103286440196
# 66
# [15, 10, 1.0] dual hidden layers plus cross-entropy
# 0.4066500663757324
# 0.1294946503040047
# 43
# [15, 10, 1.0] dual hidden layers plus quadratic
# 0.42832326889038086
# 0.13284117436840637
# 55
# [15, 10, 3.0] single hidden layer plus cross-entropy
# 0.22068166732788086
# 0.07176079722726986
# 84
# [15, 10, 3.0] single hidden layer plus quadratic
# 0.24316763877868652
# 0.08039904551230008
# 63
# [15, 10, 3.0] dual hidden layers plus cross-entropy
# 0.427382230758667
# 0.12167066662012618
# 11
# [15, 10, 3.0] dual hidden layers plus quadratic
# 0.4060206413269043
# 0.1628068313014261
# 63
# [15, 10, 5.0] single hidden layer plus cross-entropy
# 0.20857477188110352
# 0.26872633901441195
# 96
# [15, 10, 5.0] single hidden layer plus quadratic
# 0.24569129943847656
# 0.1437229092169467
# 35
# [15, 10, 5.0] dual hidden layers plus cross-entropy
# 0.42282748222351074
# 0.10768584024793822
# 13
# [15, 10, 5.0] dual hidden layers plus quadratic
# 0.45088648796081543
# 0.12151992539790303
# 35
# [15, 20, 0.1] single hidden layer plus cross-entropy
# 0.2252957820892334
# 0.11264360864664502
# 79
# [15, 20, 0.1] single hidden layer plus quadratic
# 0.23786282539367676
# 0.15575870484860402
# 93
# [15, 20, 0.1] dual hidden layers plus cross-entropy
# 0.4144306182861328
# 0.1322879159021716
# 97
# [15, 20, 0.1] dual hidden layers plus quadratic
# 0.4347517490386963
# 0.17827427626233236
# 93
# [15, 20, 0.5] single hidden layer plus cross-entropy
# 0.23955488204956055
# 0.08186632725245667
# 8
# [15, 20, 0.5] single hidden layer plus quadratic
# 0.2711632251739502
# 0.12751989876053219
# 73
# [15, 20, 0.5] dual hidden layers plus cross-entropy
# 0.4141829013824463
# 0.13039782214709328
# 53
# [15, 20, 0.5] dual hidden layers plus quadratic
# 0.4463047981262207
# 0.13624003595315634
# 93
# [15, 20, 1.0] single hidden layer plus cross-entropy
# 0.2762317657470703
# 0.09812153749114924
# 59
# [15, 20, 1.0] single hidden layer plus quadratic
# 0.26432013511657715
# 0.16299124205761004
# 54
# [15, 20, 1.0] dual hidden layers plus cross-entropy
# 0.4138333797454834
# 0.11627730242120829
# 33
# [15, 20, 1.0] dual hidden layers plus quadratic
# 0.41173720359802246
# 0.13695200246644995
# 25
# [15, 20, 3.0] single hidden layer plus cross-entropy
# 0.22823691368103027
# 0.0635329614896299
# 52
# [15, 20, 3.0] single hidden layer plus quadratic
# 0.255939245223999
# 0.12900668841377633
# 63
# [15, 20, 3.0] dual hidden layers plus cross-entropy
# 0.3933098316192627
# 0.08451212038419764
# 95
# [15, 20, 3.0] dual hidden layers plus quadratic
# 0.4227945804595947
# 0.13100247529672435
# 28
# [15, 20, 5.0] single hidden layer plus cross-entropy
# 0.22621369361877441
# 0.1646031547740334
# 59
# [15, 20, 5.0] single hidden layer plus quadratic
# 0.28632164001464844
# 0.18528769389181124
# 34
# [15, 20, 5.0] dual hidden layers plus cross-entropy
# 0.4293489456176758
# 0.11738440988649065
# 53
# [15, 20, 5.0] dual hidden layers plus quadratic
# 0.4604640007019043
# 0.13738715635604914
# 76
# [15, 100, 0.1] single hidden layer plus cross-entropy
# 0.22109031677246094
# 0.17013362856777342
# 95
# [15, 100, 0.1] single hidden layer plus quadratic
# 0.2571141719818115
# 0.7912555935320364
# 3
# [15, 100, 0.1] dual hidden layers plus cross-entropy
# 0.413618803024292
# 0.1850538656622901
# 61
# [15, 100, 0.1] dual hidden layers plus quadratic
# 0.4415147304534912
# 0.6289490370487327
# 54
# [15, 100, 0.5] single hidden layer plus cross-entropy
# 0.2148892879486084
# 0.12670033096213326
# 61
# [15, 100, 0.5] single hidden layer plus quadratic
# 0.2624964714050293
# 0.17100003426944957
# 61
# [15, 100, 0.5] dual hidden layers plus cross-entropy
# 0.4040076732635498
# 0.13100450519630188
# 93
# [15, 100, 0.5] dual hidden layers plus quadratic
# 0.4355323314666748
# 0.1721227004047155
# 25
# [15, 100, 1.0] single hidden layer plus cross-entropy
# 0.23322248458862305
# 0.10896611777425178
# 82
# [15, 100, 1.0] single hidden layer plus quadratic
# 0.2621479034423828
# 0.1452763163395622
# 64
# [15, 100, 1.0] dual hidden layers plus cross-entropy
# 0.4331543445587158
# 0.13422238696411334
# 95
# [15, 100, 1.0] dual hidden layers plus quadratic
# 0.4485201835632324
# 0.14119970794887893
# 95
# [15, 100, 3.0] single hidden layer plus cross-entropy
# 0.243178129196167
# 0.1260680116351811
# 47
# [15, 100, 3.0] single hidden layer plus quadratic
# 0.26048779487609863
# 0.15207723284028818
# 79
# [15, 100, 3.0] dual hidden layers plus cross-entropy
# 0.39659762382507324
# 0.13343507692464568
# 33
# [15, 100, 3.0] dual hidden layers plus quadratic
# 0.45705389976501465
# 0.13641177156106102
# 9
# [15, 100, 5.0] single hidden layer plus cross-entropy
# 0.2340848445892334
# 0.14370629504076443
# 26
# [15, 100, 5.0] single hidden layer plus quadratic
# 0.29267001152038574
# 0.1480486467683334
# 82
# [15, 100, 5.0] dual hidden layers plus cross-entropy
# 0.42411351203918457
# 0.1383410758643632
# 48
# [15, 100, 5.0] dual hidden layers plus quadratic
# 0.51310133934021
# 0.13477553458125993
# 28
# [30, 5, 0.1] single hidden layer plus cross-entropy
# 0.48572874069213867
# 0.1501851166426637
# 59
# [30, 5, 0.1] single hidden layer plus quadratic
# 0.5381052494049072
# 0.16446300077986567
# 12
# [30, 5, 0.1] dual hidden layers plus cross-entropy
# 0.853724479675293
# 0.13237619136798717
# 65
# [30, 5, 0.1] dual hidden layers plus quadratic
# 0.8767890930175781
# 0.1340373075616477
# 79
# [30, 5, 0.5] single hidden layer plus cross-entropy
# 0.503394603729248
# 0.06097465730212683
# 66
# [30, 5, 0.5] single hidden layer plus quadratic
# 0.5382182598114014
# 0.13855831420143785
# 63
# [30, 5, 0.5] dual hidden layers plus cross-entropy
# 0.8111028671264648
# 0.030013870474298474
# 84
# [30, 5, 0.5] dual hidden layers plus quadratic
# 0.8549168109893799
# 0.15820430114108733
# 0
# [30, 5, 1.0] single hidden layer plus cross-entropy
# 0.4661366939544678
# 0.03674354881831704
# 59
# [30, 5, 1.0] single hidden layer plus quadratic
# 0.5498013496398926
# 0.14961123942921042
# 11
# [30, 5, 1.0] dual hidden layers plus cross-entropy
# 0.8584918975830078
# 0.058442994382860665
# 84
# [30, 5, 1.0] dual hidden layers plus quadratic
# 1.4075758457183838
# 0.16962360825081757
# 23
# [30, 5, 3.0] single hidden layer plus cross-entropy
# 0.47748470306396484
# 0.031376819986387874
# 59
# [30, 5, 3.0] single hidden layer plus quadratic
# 0.5363850593566895
# 0.05796730135107845
# 11
# [30, 5, 3.0] dual hidden layers plus cross-entropy
# 0.8503818511962891
# 0.07228511200810327
# 38
# [30, 5, 3.0] dual hidden layers plus quadratic
# 0.9109721183776855
# 0.12740389248608255
# 97
# [30, 5, 5.0] single hidden layer plus cross-entropy
# 0.4801063537597656
# 0.10575389255343601
# 46
# [30, 5, 5.0] single hidden layer plus quadratic
# 0.5276319980621338
# 0.15242251879069377
# 47
# [30, 5, 5.0] dual hidden layers plus cross-entropy
# 0.8527216911315918
# 0.14097083734373098
# 98
# [30, 5, 5.0] dual hidden layers plus quadratic
# 1.6930112838745117
# 0.1350042769094246
# 97
# [30, 10, 0.1] single hidden layer plus cross-entropy
# 1.3416872024536133
# 0.1164976440946313
# 22
# [30, 10, 0.1] single hidden layer plus quadratic
# 0.9930167198181152
# 0.1253205075877211
# 79
# [30, 10, 0.1] dual hidden layers plus cross-entropy
# 0.8149940967559814
# 0.1261146214821989
# 99
# [30, 10, 0.1] dual hidden layers plus quadratic
# 0.8280212879180908
# 0.13585311714878281
# 93
# [30, 10, 0.5] single hidden layer plus cross-entropy
# 0.47628283500671387
# 0.0572038622040903
# 23
# [30, 10, 0.5] single hidden layer plus quadratic
# 0.5595088005065918
# 0.16856947414379833
# 11
# [30, 10, 0.5] dual hidden layers plus cross-entropy
# 0.7661192417144775
# 0.08055356267692979
# 11
# [30, 10, 0.5] dual hidden layers plus quadratic
# 0.8243041038513184
# 0.14042556592199865
# 85
# [30, 10, 1.0] single hidden layer plus cross-entropy
# 0.44614577293395996
# 0.05926913413509624
# 47
# [30, 10, 1.0] single hidden layer plus quadratic
# 0.5299060344696045
# 0.1452840497523906
# 11
# [30, 10, 1.0] dual hidden layers plus cross-entropy
# 0.8067562580108643
# 0.03683797758757091
# 87
# [30, 10, 1.0] dual hidden layers plus quadratic
# 0.8608932495117188
# 0.14640626572975396
# 35
# [30, 10, 3.0] single hidden layer plus cross-entropy
# 0.4767460823059082
# 0.07680435195804292
# 44
# [30, 10, 3.0] single hidden layer plus quadratic
# 0.4943811893463135
# 0.1106900822860257
# 66
# [30, 10, 3.0] dual hidden layers plus cross-entropy
# 0.7918689250946045
# 0.06376346710292156
# 97
# [30, 10, 3.0] dual hidden layers plus quadratic
# 0.8628582954406738
# 0.13109205716754474
# 97
# [30, 10, 5.0] single hidden layer plus cross-entropy
# 0.4806485176086426
# 0.10067456030441121
# 83
# [30, 10, 5.0] single hidden layer plus quadratic
# 0.5299103260040283
# 0.09635720437048871
# 8
# [30, 10, 5.0] dual hidden layers plus cross-entropy
# 0.7761833667755127
# 0.21479816920035294
# 6
# [30, 10, 5.0] dual hidden layers plus quadratic
# 0.8382351398468018
# 0.1861441874103197
# 15
# [30, 20, 0.1] single hidden layer plus cross-entropy
# 0.45578670501708984
# 0.13114292974198766
# 53
# [30, 20, 0.1] single hidden layer plus quadratic
# 0.5311248302459717
# 0.14027045231965057
# 95
# [30, 20, 0.1] dual hidden layers plus cross-entropy
# 0.8189785480499268
# 0.13323553819034528
# 87
# [30, 20, 0.1] dual hidden layers plus quadratic
# 0.849581241607666
# 0.1531406771571337
# 48
# [30, 20, 0.5] single hidden layer plus cross-entropy
# 0.4824831485748291
# 0.13262458980218134
# 59
# [30, 20, 0.5] single hidden layer plus quadratic
# 0.4942030906677246
# 0.174638860091161
# 4
# [30, 20, 0.5] dual hidden layers plus cross-entropy
# 0.7958173751831055
# 0.10998468738634305
# 61
# [30, 20, 0.5] dual hidden layers plus quadratic
# 0.8787524700164795
# 0.13862265285782466
# 48
# [30, 20, 1.0] single hidden layer plus cross-entropy
# 0.5235276222229004
# 0.07668851032825161
# 11
# [30, 20, 1.0] single hidden layer plus quadratic
# 0.48009324073791504
# 0.16940929013743086
# 63
# [30, 20, 1.0] dual hidden layers plus cross-entropy
# 0.7601168155670166
# 0.08555182931883544
# 11
# [30, 20, 1.0] dual hidden layers plus quadratic
# 0.8511385917663574
# 0.1634257095998976
# 51
# [30, 20, 3.0] single hidden layer plus cross-entropy
# 0.490159273147583
# 0.08165018611713376
# 87
# [30, 20, 3.0] single hidden layer plus quadratic
# 0.5559794902801514
# 0.15501292706303874
# 47
# [30, 20, 3.0] dual hidden layers plus cross-entropy
# 0.8420469760894775
# 0.14106112078348831
# 54
# [30, 20, 3.0] dual hidden layers plus quadratic
# 0.854541540145874
# 0.1695663362189318
# 17
# [30, 20, 5.0] single hidden layer plus cross-entropy
# 0.47300219535827637
# 0.08080088554340285
# 95
# [30, 20, 5.0] single hidden layer plus quadratic
# 0.52886962890625
# 0.12803538835620534
# 23
# [30, 20, 5.0] dual hidden layers plus cross-entropy
# 0.795194149017334
# 0.07352692844525537
# 54
# [30, 20, 5.0] dual hidden layers plus quadratic
# 0.8457567691802979
# 0.15902006075444508
# 43
# [30, 100, 0.1] single hidden layer plus cross-entropy
# 0.4784047603607178
# 0.1301878691859689
# 9
# [30, 100, 0.1] single hidden layer plus quadratic
# 0.4973318576812744
# 0.2747532619728971
# 93
# [30, 100, 0.1] dual hidden layers plus cross-entropy
# 0.7834732532501221
# 0.14214751479783733
# 87
# [30, 100, 0.1] dual hidden layers plus quadratic
# 0.8422422409057617
# 0.2882090210171986
# 93
# [30, 100, 0.5] single hidden layer plus cross-entropy
# 0.4753539562225342
# 0.11618713623552201
# 35
# [30, 100, 0.5] single hidden layer plus quadratic
# 0.4965651035308838
# 0.1350006443818582
# 79
# [30, 100, 0.5] dual hidden layers plus cross-entropy
# 0.78324294090271
# 0.13011136493086944
# 48
# [30, 100, 0.5] dual hidden layers plus quadratic
# 0.8145420551300049
# 0.14808689288419508
# 93
# [30, 100, 1.0] single hidden layer plus cross-entropy
# 0.4933204650878906
# 0.11923614309750843
# 11
# [30, 100, 1.0] single hidden layer plus quadratic
# 0.5158495903015137
# 0.13565405985950812
# 64
# [30, 100, 1.0] dual hidden layers plus cross-entropy
# 0.7748417854309082
# 0.12974318224698125
# 51
# [30, 100, 1.0] dual hidden layers plus quadratic
# 0.8321864604949951
# 0.13635632118324237
# 79
# [30, 100, 3.0] single hidden layer plus cross-entropy
# 0.45288848876953125
# 0.11207496693957451
# 35
# [30, 100, 3.0] single hidden layer plus quadratic
# 0.505042552947998
# 0.1806202490759197
# 35
# [30, 100, 3.0] dual hidden layers plus cross-entropy
# 0.7450053691864014
# 0.10103426086874746
# 94
# [30, 100, 3.0] dual hidden layers plus quadratic
# 0.8200349807739258
# 0.1371827307455625
# 25
# [30, 100, 5.0] single hidden layer plus cross-entropy
# 0.44208765029907227
# 0.06306282007939391
# 24
# [30, 100, 5.0] single hidden layer plus quadratic
# 0.49820423126220703
# 0.19508034998609655
# 41
# [30, 100, 5.0] dual hidden layers plus cross-entropy
# 0.7994656562805176
# 0.12995818822172314
# 82
# [30, 100, 5.0] dual hidden layers plus quadratic
# 0.8335967063903809
# 0.14374855155552338
# 12
# [45, 5, 0.1] single hidden layer plus cross-entropy
# 0.7502872943878174
# 0.08935081997923189
# 66
# [45, 5, 0.1] single hidden layer plus quadratic
# 0.7810981273651123
# 0.15435787553322686
# 61
# [45, 5, 0.1] dual hidden layers plus cross-entropy
# 1.1987638473510742
# 0.1304607925313443
# 11
# [45, 5, 0.1] dual hidden layers plus quadratic
# 1.2684381008148193
# 0.13907609864289336
# 48
# [45, 5, 0.5] single hidden layer plus cross-entropy
# 0.6752984523773193
# 0.050510338574484843
# 44
# [45, 5, 0.5] single hidden layer plus quadratic
# 0.7677679061889648
# 0.08990705923723746
# 8
# [45, 5, 0.5] dual hidden layers plus cross-entropy
# 1.2008380889892578
# 0.103252322591572
# 92
# [45, 5, 0.5] dual hidden layers plus quadratic
# 1.2527861595153809
# 0.15489961049526652
# 11
# [45, 5, 1.0] single hidden layer plus cross-entropy
# 0.743227481842041
# 0.052178007337450684
# 59
# [45, 5, 1.0] single hidden layer plus quadratic
# 0.7552802562713623
# 0.10916899426213024
# 44
# [45, 5, 1.0] dual hidden layers plus cross-entropy
# 1.2780141830444336
# 0.12017549630208205
# 18
# [45, 5, 1.0] dual hidden layers plus quadratic
# 1.3168621063232422
# 0.15028639701076393
# 11
# [45, 5, 3.0] single hidden layer plus cross-entropy
# 0.71872878074646
# 0.1412027329908549
# 42
# [45, 5, 3.0] single hidden layer plus quadratic
# 0.7688281536102295
# 0.12328770356236597
# 47
# [45, 5, 3.0] dual hidden layers plus cross-entropy
# 1.2019164562225342
# 0.08425042666715872
# 8
# [45, 5, 3.0] dual hidden layers plus quadratic
# 1.296280860900879
# 0.13787319947831028
# 53
# [45, 5, 5.0] single hidden layer plus cross-entropy
# 0.7117266654968262
# 0.24538314787018378
# 7
# [45, 5, 5.0] single hidden layer plus quadratic
# 0.7802841663360596
# 0.04069306753749835
# 44
# [45, 5, 5.0] dual hidden layers plus cross-entropy
# 1.2349348068237305
# 0.26509036703101524
# 88
# [45, 5, 5.0] dual hidden layers plus quadratic
# 1.3319354057312012
# 0.06832119517757274
# 44
# [45, 10, 0.1] single hidden layer plus cross-entropy
# 0.6749701499938965
# 0.11315224059542998
# 11
# [45, 10, 0.1] single hidden layer plus quadratic
# 0.7494757175445557
# 0.13259360048423047
# 9
# [45, 10, 0.1] dual hidden layers plus cross-entropy
# 1.1769771575927734
# 0.10990488198041237
# 8
# [45, 10, 0.1] dual hidden layers plus quadratic
# 1.2512972354888916
# 0.13238036711930457
# 47
# [45, 10, 0.5] single hidden layer plus cross-entropy
# 0.708683967590332
# 0.05755480748096847
# 47
# [45, 10, 0.5] single hidden layer plus quadratic
# 0.7924182415008545
# 0.1712834875132123
# 35
# [45, 10, 0.5] dual hidden layers plus cross-entropy
# 1.1600120067596436
# 0.0734907599104901
# 11
# [45, 10, 0.5] dual hidden layers plus quadratic
# 1.2995390892028809
# 0.16614374055949893
# 61
# [45, 10, 1.0] single hidden layer plus cross-entropy
# 0.6943719387054443
# 0.05510751333990165
# 34
# [45, 10, 1.0] single hidden layer plus quadratic
# 0.7462694644927979
# 0.1503789008275967
# 47
# [45, 10, 1.0] dual hidden layers plus cross-entropy
# 1.1532630920410156
# 0.09381135043338883
# 22
# [45, 10, 1.0] dual hidden layers plus quadratic
# 1.2637765407562256
# 0.14150171646008505
# 59
# [45, 10, 3.0] single hidden layer plus cross-entropy
# 0.6936383247375488
# 0.05723282369851247
# 64
# [45, 10, 3.0] single hidden layer plus quadratic
# 0.782111406326294
# 0.13031436798164275
# 34
# [45, 10, 3.0] dual hidden layers plus cross-entropy
# 1.164499282836914
# 0.035141544944209846
# 22
# [45, 10, 3.0] dual hidden layers plus quadratic
# 1.2541985511779785
# 0.17760421874611537
# 44
# [45, 10, 5.0] single hidden layer plus cross-entropy
# 0.7515919208526611
# 0.11642196979142001
# 65
# [45, 10, 5.0] single hidden layer plus quadratic
# 0.7449302673339844
# 0.09624374363091157
# 23
# [45, 10, 5.0] dual hidden layers plus cross-entropy
# 1.150136947631836
# 0.1471350114732987
# 66
# [45, 10, 5.0] dual hidden layers plus quadratic
# 1.243403673171997
# 0.17998604383803468
# 63
# [45, 20, 0.1] single hidden layer plus cross-entropy
# 0.6669783592224121
# 0.09977120575885733
# 11
# [45, 20, 0.1] single hidden layer plus quadratic
# 0.799480676651001
# 0.12911589854506625
# 79
# [45, 20, 0.1] dual hidden layers plus cross-entropy
# 1.1572177410125732
# 0.1306369223228399
# 88
# [45, 20, 0.1] dual hidden layers plus quadratic
# 1.2432775497436523
# 0.13996905898772238
# 48
# [45, 20, 0.5] single hidden layer plus cross-entropy
# 0.7154135704040527
# 0.05816886633651824
# 44
# [45, 20, 0.5] single hidden layer plus quadratic
# 0.7430922985076904
# 0.17687380903444336
# 78
# [45, 20, 0.5] dual hidden layers plus cross-entropy
# 1.146819829940796
# 0.06684503882896017
# 11
# [45, 20, 0.5] dual hidden layers plus quadratic
# 1.2248077392578125
# 0.14121181793330456
# 12
# [45, 20, 1.0] single hidden layer plus cross-entropy
# 0.698584794998169
# 0.05855457777939152
# 59
# [45, 20, 1.0] single hidden layer plus quadratic
# 0.7864928245544434
# 0.14779356068066168
# 82
# [45, 20, 1.0] dual hidden layers plus cross-entropy
# 1.1616215705871582
# 0.07864378436722703
# 87
# [45, 20, 1.0] dual hidden layers plus quadratic
# 1.2677507400512695
# 0.14058920224546992
# 68
# [45, 20, 3.0] single hidden layer plus cross-entropy
# 0.6554532051086426
# 0.145118578295783
# 47
# [45, 20, 3.0] single hidden layer plus quadratic
# 0.7673265933990479
# 0.16767577109426396
# 11
# [45, 20, 3.0] dual hidden layers plus cross-entropy
# 1.2091827392578125
# 0.02293234540930086
# 87
# [45, 20, 3.0] dual hidden layers plus quadratic
# 1.215580940246582
# 0.10653481430598727
# 35
# [45, 20, 5.0] single hidden layer plus cross-entropy
# 0.7074003219604492
# 0.17785750697782274
# 22
# [45, 20, 5.0] single hidden layer plus quadratic
# 0.7370715141296387
# 0.1371954459296848
# 11
# [45, 20, 5.0] dual hidden layers plus cross-entropy
# 1.155754566192627
# 0.0590989976792689
# 87
# [45, 20, 5.0] dual hidden layers plus quadratic
# 1.3095743656158447
# 0.19424488894385514
# 33
# [45, 100, 0.1] single hidden layer plus cross-entropy
# 1.5981531143188477
# 0.12719936365589748
# 73
# [45, 100, 0.1] single hidden layer plus quadratic
# 1.5691404342651367
# 0.2329435073998624
# 79
# [45, 100, 0.1] dual hidden layers plus cross-entropy
# 1.1753427982330322
# 0.13360407075398617
# 25
# [45, 100, 0.1] dual hidden layers plus quadratic
# 1.2446050643920898
# 0.23119969573068938
# 13
# [45, 100, 0.5] single hidden layer plus cross-entropy
# 0.6697962284088135
# 0.11850421076782369
# 80
# [45, 100, 0.5] single hidden layer plus quadratic
# 0.7782840728759766
# 0.1529410519665987
# 73
# [45, 100, 0.5] dual hidden layers plus cross-entropy
# 1.1980187892913818
# 0.12973090800398587
# 21
# [45, 100, 0.5] dual hidden layers plus quadratic
# 1.2249259948730469
# 0.14131536018168495
# 48
# [45, 100, 1.0] single hidden layer plus cross-entropy
# 0.6721296310424805
# 0.12864026980648582
# 59
# [45, 100, 1.0] single hidden layer plus quadratic
# 0.7671618461608887
# 0.1504985419362908
# 6
# [45, 100, 1.0] dual hidden layers plus cross-entropy
# 1.2051117420196533
# 0.11627162631855233
# 66
# [45, 100, 1.0] dual hidden layers plus quadratic
# 1.2587404251098633
# 0.13536477769334293
# 25
# [45, 100, 3.0] single hidden layer plus cross-entropy
# 0.6746978759765625
# 0.1098221149524581
# 54
# [45, 100, 3.0] single hidden layer plus quadratic
# 0.7278573513031006
# 0.17824883379110176
# 65
# [45, 100, 3.0] dual hidden layers plus cross-entropy
# 1.14359712600708
# 0.5549480513093571
# 40
# [45, 100, 3.0] dual hidden layers plus quadratic
# 1.216515302658081
# 0.13788699949545644
# 79
# [45, 100, 5.0] single hidden layer plus cross-entropy
# 0.6772680282592773
# 0.10191142378437561
# 61
# [45, 100, 5.0] single hidden layer plus quadratic
# 0.818655252456665
# 0.16412363268265084
# 61
# [45, 100, 5.0] dual hidden layers plus cross-entropy
# 1.2269277572631836
# 0.1417599162960859
# 65
# [45, 100, 5.0] dual hidden layers plus quadratic
# 1.405336856842041
# 0.15674785280582415
# 21
# [100, 5, 0.1] single hidden layer plus cross-entropy
# 1.5096065998077393
# 0.030995237679880487
# 11
# [100, 5, 0.1] single hidden layer plus quadratic
# 1.7938308715820312
# 0.13603540523263316
# 11
# [100, 5, 0.1] dual hidden layers plus cross-entropy
# 2.7327828407287598
# 0.08978244100074423
# 38
# [100, 5, 0.1] dual hidden layers plus quadratic
# 2.938572883605957
# 0.14787561872186633
# 84
# [100, 5, 0.5] single hidden layer plus cross-entropy
# 1.5526597499847412
# 0.04923282687393257
# 11
# [100, 5, 0.5] single hidden layer plus quadratic
# 1.7754793167114258
# 0.1546019882422294
# 44
# [100, 5, 0.5] dual hidden layers plus cross-entropy
# 2.785881280899048
# 0.0559517806366656
# 11
# [100, 5, 0.5] dual hidden layers plus quadratic
# 2.914705276489258
# 0.07932676523231193
# 43
# [100, 5, 1.0] single hidden layer plus cross-entropy
# 1.6451082229614258
# 0.05206362752909498
# 61
# [100, 5, 1.0] single hidden layer plus quadratic
# 1.7700409889221191
# 0.10052238315402603
# 34
# [100, 5, 1.0] dual hidden layers plus cross-entropy
# 2.64692759513855
# 0.03615413829347383
# 53
# [100, 5, 1.0] dual hidden layers plus quadratic
# 2.874661684036255
# 0.12197594778175527
# 7
# [100, 5, 3.0] single hidden layer plus cross-entropy
# 1.6111631393432617
# 0.10861023069823093
# 34
# [100, 5, 3.0] single hidden layer plus quadratic
# 1.6986668109893799
# 0.13274723826689383
# 11
# [100, 5, 3.0] dual hidden layers plus cross-entropy
# 2.6469762325286865
# 0.18101177478803285
# 61
# [100, 5, 3.0] dual hidden layers plus quadratic
# 2.846787452697754
# 0.07225073896068178
# 96
# [100, 5, 5.0] single hidden layer plus cross-entropy
# 1.551069736480713
# 0.17780816039706646
# 87
# [100, 5, 5.0] single hidden layer plus quadratic
# 1.7024126052856445
# 0.05501888409754017
# 11
# [100, 5, 5.0] dual hidden layers plus cross-entropy
# 2.654183864593506
# 0.20386756133648448
# 31
# [100, 5, 5.0] dual hidden layers plus quadratic
# 2.8147921562194824
# 0.12078980326869906
# 97
# [100, 10, 0.1] single hidden layer plus cross-entropy
# 1.4302952289581299
# 0.06782335158693834
# 11
# [100, 10, 0.1] single hidden layer plus quadratic
# 1.6464061737060547
# 0.1771809857333299
# 61
# [100, 10, 0.1] dual hidden layers plus cross-entropy
# 2.562623977661133
# 0.07283803811775187
# 84
# [100, 10, 0.1] dual hidden layers plus quadratic
# 2.7299182415008545
# 0.14309956036817076
# 68
# [100, 10, 0.5] single hidden layer plus cross-entropy
# 1.5353889465332031
# 0.01845737489288481
# 97
# [100, 10, 0.5] single hidden layer plus quadratic
# 1.693302869796753
# 0.19116544317607334
# 59
# [100, 10, 0.5] dual hidden layers plus cross-entropy
# 2.576059341430664
# 0.03215439379137293
# 23
# [100, 10, 0.5] dual hidden layers plus quadratic
# 2.7441539764404297
# 0.14083897290695374
# 65
# [100, 10, 1.0] single hidden layer plus cross-entropy
# 1.4864764213562012
# 0.01665836124829596
# 8
# [100, 10, 1.0] single hidden layer plus quadratic
# 1.6160273551940918
# 0.059872731784394125
# 8
# [100, 10, 1.0] dual hidden layers plus cross-entropy
# 2.594252824783325
# 0.08082456536155957
# 64
# [100, 10, 1.0] dual hidden layers plus quadratic
# 2.7457563877105713
# 0.1380039906239021
# 47
# [100, 10, 3.0] single hidden layer plus cross-entropy
# 1.4896299839019775
# 0.1034516193355414
# 99
# [100, 10, 3.0] single hidden layer plus quadratic
# 1.7124176025390625
# 0.04327956949195702
# 11
# [100, 10, 3.0] dual hidden layers plus cross-entropy
# 2.6139655113220215
# 0.03309249614481301
# 84
# [100, 10, 3.0] dual hidden layers plus quadratic
# 2.7310984134674072
# 0.1369960441852983
# 87
# [100, 10, 5.0] single hidden layer plus cross-entropy
# 1.5044641494750977
# 0.1134841287450143
# 43
# [100, 10, 5.0] single hidden layer plus quadratic
# 1.7380163669586182
# 0.10600213877536799
# 11
# [100, 10, 5.0] dual hidden layers plus cross-entropy
# 2.667280673980713
# 0.10860752368716818
# 77
# [100, 10, 5.0] dual hidden layers plus quadratic
# 2.905040979385376
# 0.07142345614636303
# 43
# [100, 20, 0.1] single hidden layer plus cross-entropy
# 1.5545904636383057
# 0.11671257490856694
# 61
# [100, 20, 0.1] single hidden layer plus quadratic
# 1.6948776245117188
# 0.15828905941973664
# 48
# [100, 20, 0.1] dual hidden layers plus cross-entropy
# 2.6055750846862793
# 0.12587482119352356
# 61
# [100, 20, 0.1] dual hidden layers plus quadratic
# 2.968989610671997
# 0.13613941247147246
# 95
# [100, 20, 0.5] single hidden layer plus cross-entropy
# 1.5991604328155518
# 0.07351450818105881
# 64
# [100, 20, 0.5] single hidden layer plus quadratic
# 1.7803447246551514
# 0.18267993930826892
# 66
# [100, 20, 0.5] dual hidden layers plus cross-entropy
# 2.759232759475708
# 0.058939321909238264
# 44
# [100, 20, 0.5] dual hidden layers plus quadratic
# 2.9648096561431885
# 0.1542331671924075
# 6
# [100, 20, 1.0] single hidden layer plus cross-entropy
# 1.5820808410644531
# 0.039963321971458785
# 43
# [100, 20, 1.0] single hidden layer plus quadratic
# 1.6195707321166992
# 0.1945810814367072
# 47
# [100, 20, 1.0] dual hidden layers plus cross-entropy
# 2.6032845973968506
# 0.02712175285723148
# 65
# [100, 20, 1.0] dual hidden layers plus quadratic
# 2.7748050689697266
# 0.1470877939617222
# 11
# [100, 20, 3.0] single hidden layer plus cross-entropy
# 1.4909989833831787
# 0.03391532892778513
# 47
# [100, 20, 3.0] single hidden layer plus quadratic
# 1.650583028793335
# 0.14411286016724484
# 97
# [100, 20, 3.0] dual hidden layers plus cross-entropy
# 2.5459413528442383
# 0.04688889885522321
# 96
# [100, 20, 3.0] dual hidden layers plus quadratic
# 2.7666943073272705
# 0.1607285096457553
# 64
# [100, 20, 5.0] single hidden layer plus cross-entropy
# 1.4714486598968506
# 0.15745506259727574
# 47
# [100, 20, 5.0] single hidden layer plus quadratic
# 1.6461372375488281
# 0.09830264483699452
# 34
# [100, 20, 5.0] dual hidden layers plus cross-entropy
# 2.5560524463653564
# 0.03854211182715284
# 97
# [100, 20, 5.0] dual hidden layers plus quadratic
# 2.708916664123535
# 0.13838648046399946
# 23
# [100, 100, 0.1] single hidden layer plus cross-entropy
# 1.4845802783966064
# 0.1281798381627467
# 11
# [100, 100, 0.1] single hidden layer plus quadratic
# 1.6308176517486572
# 0.15234840362286012
# 95
# [100, 100, 0.1] dual hidden layers plus cross-entropy
# 2.428640127182007
# 0.13161097350504475
# 93
# [100, 100, 0.1] dual hidden layers plus quadratic
# 2.631671667098999
# 0.16632078926577362
# 79
# [100, 100, 0.5] single hidden layer plus cross-entropy
# 1.4500377178192139
# 0.13704834811804578
# 59
# [100, 100, 0.5] single hidden layer plus quadratic
# 1.679182529449463
# 0.16421567686623464
# 19
# [100, 100, 0.5] dual hidden layers plus cross-entropy
# 2.464573860168457
# 0.11794675979280446
# 66
# [100, 100, 0.5] dual hidden layers plus quadratic
# 2.703643798828125
# 0.13597507764911668
# 28
# [100, 100, 1.0] single hidden layer plus cross-entropy
# 1.4367389678955078
# 0.05149119608902512
# 11
# [100, 100, 1.0] single hidden layer plus quadratic
# 1.6265559196472168
# 0.1597242662685997
# 82
# [100, 100, 1.0] dual hidden layers plus cross-entropy
# 2.4346401691436768
# 0.1273076062511606
# 61
# [100, 100, 1.0] dual hidden layers plus quadratic
# 2.684030532836914
# 0.1359920572600062
# 12
# [100, 100, 3.0] single hidden layer plus cross-entropy
# 1.4047904014587402
# 0.03400920828145934
# 11
# [100, 100, 3.0] single hidden layer plus quadratic
# 1.5834441184997559
# 0.11741064347473217
# 35
# [100, 100, 3.0] dual hidden layers plus cross-entropy
# 2.5321342945098877
# 0.08527756075621912
# 70
# [100, 100, 3.0] dual hidden layers plus quadratic
# 2.620025873184204
# 0.15914173844048163
# 32
# [100, 100, 5.0] single hidden layer plus cross-entropy
# 1.4910788536071777
# 0.1408941740985955
# 46
# [100, 100, 5.0] single hidden layer plus quadratic
# 1.6668200492858887
# 0.18294977046964334
# 34
# [100, 100, 5.0] dual hidden layers plus cross-entropy
# 2.5413107872009277
# 0.04087045634875685
# 2
# [100, 100, 5.0] dual hidden layers plus quadratic
# 2.7008488178253174
# 0.15074682462407665
# 16

# %%
import matplotlib.pyplot as plt

# pre-process our really janked up data ... first the training_times
training_timesSingle1 = training_times[0::4]
training_timesSingle2 = training_times[1::4]
training_timesDouble1 = training_times[2::4]
training_timesDouble2 = training_times[3::4]
training_timesSingle = []
training_timesDouble = []

for tt1, tt2 in zip(training_timesSingle1, training_timesSingle2):
 training_timesSingle.append(tt1)
 training_timesSingle.append(tt2)

for tt1, tt2 in zip(training_timesDouble1, training_timesDouble2):
 training_timesDouble.append(tt1)
 training_timesDouble.append(tt2)

# and now the accuracies...
accuraciesSingle1 = accuracies[0::4]
accuraciesSingle2 = accuracies[1::4]
accuraciesDouble1 = accuracies[2::4]
accuraciesDouble2 = accuracies[3::4]
accuraciesSingle = []
accuraciesDouble = []

for acc1, acc2 in zip(accuraciesSingle1, accuraciesSingle2):
 accuraciesSingle.append(acc1[1][-1])
 accuraciesSingle.append(acc2[1][-1])

for acc1, acc2 in zip(accuraciesDouble1, accuraciesDouble2):
 accuraciesDouble.append(acc1[1][-1])
 accuraciesDouble.append(acc2[1][-1])

# and now the labels
labelsSingle = []
labelsDouble = []

for config in configs:
 labelsSingle.append(f"{config}-cross-784-15-10")
 labelsSingle.append(f"{config}-quad-784-15-10")
 labelsDouble.append(f"{config}-cross-784-30-15-10")
 labelsDouble.append(f"{config}-quad-784-30-15-10")

plt.subplots(figsize=(50,10))
plt.plot(labelsSingle, accuraciesSingle)
plt.show()
plt.plot(labelsDouble, training_timesDouble)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a234176603d6> in <module>
#      46 plt.plot(labelsSingle, accuraciesSingle)
#      47 plt.show()
# ---> 48 plt.plot(labelsDouble, training_timesDouble)
#      49 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (160,) and (80,)

# %%
label_learningrate = []
tt_learningrate = []
acc_learningrate = []

for i, config in enumerate(configs):
  if config[0] == 30 and config[1] == 10:
    label_learningrate.append(labelsSingle[2*i+1])
    tt_learningrate.append(training_timesSingle[2*i+1]) # i+1 b/c i is the cross entropy cost and we want quadratic
    acc_learningrate.append(accuraciesSingle[2*i+1]) # i+1 b/c i is the cross entropy cost and we want quadratic

print(label_learningrate)
print(tt_learningrate)
print(acc_learningrate)

plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, tt_learningrate)
plt.show()
plt.subplots(figsize=(20,6))
plt.plot(label_learningrate, acc_learningrate)
plt.show
# Out:
# ['[30, 10, 0.1]-quad-784-15-10', '[30, 10, 0.5]-quad-784-15-10', '[30, 10, 1.0]-quad-784-15-10', '[30, 10, 3.0]-quad-784-15-10', '[30, 10, 5.0]-quad-784-15-10']
# [1.2432775497436523, 1.2677507400512695, 1.3095743656158447, 1.2249259948730469, 1.216515302658081]
# [33, 63, 67, 72, 67]
# <function matplotlib.pyplot.show(*args, **kw)>
